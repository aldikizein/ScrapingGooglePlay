# %%
import pandas as pd

# %%
pip install google_play_scraper
# Out:
# Collecting google_play_scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.3 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google_play_scraper
# Successfully installed google_play_scraper-1.2.7

# %%
from google_play_scraper import Sort, reviews
from google_play_scraper import app
import numpy as np

# %%
result, continuation_token = reviews(
    'gov.dukcapil.mobile_id',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=1000,
    filter_score_with= None
)

# %%
data = pd.DataFrame(np.array(result),columns=['review'])
data = data.join(pd.DataFrame(data.pop('review').tolist()))
data.head()
# Out:
#                                reviewId           userName  \
# 0  25f0ca6b-6129-4150-a015-d8bfd82b3e5c           iman bio
# 1  f0cc8bf6-e0f6-4225-9377-c49abe55f6e4         Novitasari
# 2  00098ede-09b9-4d21-be15-c3059561ede3    Fitri Audila983
# 3  d5fe3ac1-f88a-4fdd-b81d-179929f10c42         Dini Arini
# 4  17009a3d-e3f6-4849-bdf7-5d795e27c2e7  Thareq abdul aziz
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Apa ini?? Fitur BAGIKAN drngan cara scan barco...      1             23
# 1  Wahh wahhh saya sebagai lulusan teknik informa...      1           1275
# 2  Perbaiki lagi deh apl nya, untuk aktivasi saja...      1            193
# 3  Aplikasi ini memiliki potensi besar untuk memp...      1            170
# 4  Masa sekelas dukcapil ga punya tim it yg mempu...      1            203
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0                1.2.2 2024-12-06 05:22:07         None      None      1.2.2
# 1                1.2.2 2024-10-20 05:27:48         None      None      1.2.2
# 2                1.2.2 2024-10-29 16:08:38         None      None      1.2.2
# 3                1.2.2 2024-11-09 05:37:11         None      None      1.2.2
# 4                1.2.2 2024-10-24 03:20:21         None      None      1.2.2

# %%
data = data[['content','score']]
data.head()
# Out:
#                                              content  score
# 0  Apa ini?? Fitur BAGIKAN drngan cara scan barco...      1
# 1  Wahh wahhh saya sebagai lulusan teknik informa...      1
# 2  Perbaiki lagi deh apl nya, untuk aktivasi saja...      1
# 3  Aplikasi ini memiliki potensi besar untuk memp...      1
# 4  Masa sekelas dukcapil ga punya tim it yg mempu...      1

# %%
len(data)
# Out:
# 1000

# %%
data.tail()
# Out:
#                                                content  score
# 995  Udah di isi data pendaftaran, udah di foto waj...      1
# 996  Aplikasi nya bagus Tapi uda lama daftarkan ana...      1
# 997  smartphone 4G dan pake Wifi di rumah, tapi unt...      3
# 998  aplikasi kurang jelas menurut saya, di sini ad...      2
# 999  Meskipun katanya digital, ktp fisik dan foto c...      1

# %%
data.to_csv("Ulasan Identitas Kependudukan Digital Data.csv", index = False  , encoding='utf-8')
